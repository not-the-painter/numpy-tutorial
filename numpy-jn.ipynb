# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = a.dot(b)

# %%
print(c)
# Out:
# 32

# %%
a
# Out:
# array([1, 2, 3])

# %%
print(a + b)
a + b
# Out:
# [5 7 9]
# array([5, 7, 9])

# %%
M = np.array([[1, 2], [3, 4]])
print(M)
# Out:
# [[1 2]
#  [3 4]]

# %%
N = np.array([[5, 6], [7, 8]])
print(N)
# Out:
# [[5 6]
#  [7 8]]

# %%
P = M @ N
print(P)
# Out:
# [[19 22]
#  [43 50]]

# %%
A = np.matrix([a, b])
S = np.linalg.svd(A)
print(S)
# Out:
# SVDResult(U=matrix([[-0.3863177 , -0.92236578],
#         [-0.92236578,  0.3863177 ]]), S=array([9.508032  , 0.77286964]), Vh=matrix([[-0.42866713, -0.56630692, -0.7039467 ],
#         [ 0.80596391,  0.11238241, -0.58119908],
#         [ 0.40824829, -0.81649658,  0.40824829]]))
